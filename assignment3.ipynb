# %%
# 1 make a calculator using python with addition, subtraction, multiplication, division and power
num1 = float(input("Enter the first number: "))
operator = input("Enter an operator(+ - * / **): ")
num2 = float(input("Enter the second number: "))

if operator == "+":
    result = num1 + num2
    print(result)
elif operator == "-":
    result = num1 - num2
    print(result)
elif operator == "*":
    result = num1 * num2
    print(result)
elif operator == "/":
    result = num1 / num2
    print(result)
elif operator == "**":
    result = num1 ** num2
    print(result)
else:
    print("Please insert correct operator")

# %%
# 2 write a program to check if there is any numeric value in list using for loop
lists = [2.5, 100, 2 , "cat"]
num1 = int(input("Enter the number:"))
found = False
for checknum in lists:
    if checknum == num1:
        found = True
        break
        
print(f"Number {num1} is on the list" if found else f"The number {num1} is not on the list!")
# Out:
# Enter the number: 2
# Number 2 is on the list

# %%
# 3 write a python script to add a key to a dictionary
values = {"a": 1, "b": 2}

values["c"] = 3

print(values)
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
# 4 write a python program to sum all the numerics items in a dictionary
num2 = {'a': 100, 'b': 200, 'c': 300}
res = sum(num2.values())
print(res)
# Out:
# 600

# %%
# 5 write a python program to identify duplicate values from list
lis = [1,2,2,3,4,5,5,7,9,1]
uni=[]
dup=[]

for ele in lis:
    if ele not in uni:
        uni.append(ele)
    elif ele not in dup:
        dup.append(ele)
# print(uni)
print(dup)
# Out:
# [2, 5, 1]

# %%
# 6 write a python script to check if a given key already exists in a dictionary
my_dictionary = {'Pete':95, 'jack':62, 'George':75}
key_check = input("Enter the Key:")
if key_check in my_dictionary.keys():
    print("Key is Exists!")
    print(my_dictionary[key_check])
else:
    print("Key does not exist")
# Out:
# Enter the Key: jack
# Key is Exists!
# 62
